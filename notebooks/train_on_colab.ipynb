# %% [markdown]
# # OncoLens Colab Training
# Train the LC25000 classifier on a Google Colab GPU and save outputs to Google Drive or Hugging Face Hub.

# %%
# !git clone https://github.com/Sirpak/OncoLens.git
# %cd OncoLens
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
DATASET_PATH = '/content/drive/MyDrive/LC25000/lung_colon_image_set'
OUTPUT_DIR = '/content/drive/MyDrive/OncoLens/runs/exp1'
HF_REPO_ID = ''  # optional

# %%
# Optional: enable Hugging Face Hub uploads
# import os
# os.environ['HF_TOKEN'] = 'your-token'

# %%
# !python src/train.py --config config/config.yaml --dataset-path "$DATASET_PATH" --output-dir "$OUTPUT_DIR"
